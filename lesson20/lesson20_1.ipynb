# %%
import matplotlib.pyplot as plt
import numpy as np

figure=plt.figure()     #top function
axes = figure.add_subplot() #figure的實體method()
data = np.arange(10,20)
axes.plot(data)
plt.show()

# %%
data = np.arange(10,20)
plt.plot(data)      #在ipynb裡用這個寫法top function會自動產生figure及axes的實體

# %%
import numpy as np
fig=plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
#“standard normal” distribution  統計學裡稱為 常態分佈
#np.random.randn(50) #-1~1之間會佔百分之67,自動建立一個常態分佈的亂數

#numpy的實體方法
#numpy.cumsum(a, axis=None, dtype=None, out=None)
#plt.plot(np.random.randn(50).cumsum(),'k--')
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)  #bins=20個長條形    histogram看數值分佈?
ax2.scatter(np.arange(30),np.arange(30)+ (3 * np.random.randn(30)))#第1個是代表X軸是0~29、第2個是代表Y軸是0~29
ax3.plot(np.random.randn(50).cumsum(),'k--')
np.random.randn(10)
# Out:
# array([ 0.36674194, -0.09916264, -0.58643975,  0.65099884,  0.18896206,
#        -1.95280078, -0.29685667, -0.65809015, -1.94478405, -0.32065751])

# %%
#同時建立figure,axes
#top function--> subplots
#fig,axes = plt.subplots(2,2)
print(type(fig))
print(type(axes))
print(axes)
fig,axes = plt.subplots(2,2,sharex=True,sharey=True)    #sharex共用X軸、sharey共用Y軸
for i in range(2):
    for j in range(2):
        #print(i,j)
        axes[i,j].hist(np.random.randn(100),bins=50,color='k',alpha=0.3) 
fig.subplots_adjust(wspace=0,hspace=0)   #wspace寬之間的距離、hspace高的
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'numpy.ndarray'>
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %%
data = np.random.randn(30).cumsum()
plt.plot(data,'b--',label='Default')
plt.plot(data,'y-',drawstyle = 'steps-post',label='s-p')
plt.legend(loc='best')
