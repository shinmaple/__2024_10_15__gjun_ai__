# %%
import numpy as np
fivestore = np.random.randint(100,10000,size=(5,30))
fivestore_cumsum = fivestore.cumsum(axis=1)
fivestore_cumsum
# Out:
# array([[  3936,  10456,  15748,  21104,  23092,  27183,  31850,  33983,
#          39239,  42339,  51624,  54331,  58134,  62218,  67058,  69265,
#          71713,  73590,  82008,  82912,  83987,  89728,  95123,  96763,
#         102660, 109192, 110783, 113993, 123596, 128387],
#        [  5202,  10428,  11356,  14281,  23501,  30665,  35895,  42937,
#          45048,  46500,  47682,  51064,  56921,  60255,  67321,  69904,
#          79562,  88591,  91590,  98866, 105408, 112365, 120358, 123479,
#         128247, 136686, 137825, 144527, 153769, 157004],
#        [  5832,  10261,  15488,  20175,  28908,  31671,  37918,  38408,
#          45435,  51419,  60158,  61329,  71017,  78368,  79399,  88963,
#          90105,  91090,  96734, 105759, 109890, 117168, 121115, 131114,
#         139412, 141318, 149134, 154519, 156924, 157028],
#        [  4400,   7196,  15745,  16205,  23436,  27167,  34827,  39541,
#          40225,  47832,  56926,  58935,  60205,  67357,  77310,  82252,
# ...

# %%
import pandas as pd
fivestore = pd.DataFrame(fivestore_cumsum,
             columns=[f"第{day}天" for day in range(1,31)],
             index=["A1分店","A2分店","A3分店","A4分店","A5分店"])
fivestore.T
# Out:
#         A1分店    A2分店    A3分店    A4分店    A5分店
# 第1天     2939    2273    9640    8101    1196
# 第2天     9168   10675   16375   12864    8894
# 第3天    15870   14955   25204   14609    9309
# 第4天    18171   18110   32509   17809   10294
# 第5天    24953   26189   33298   18352   14662
# 第6天    30875   31148   36688   23195   20354
# 第7天    33984   40599   41365   28231   29700
# 第8天    43437   47274   46511   35209   30919
# 第9天    44444   50136   54633   44141   39238
# 第10天   49423   56253   57606   53349   48794
# 第11天   59133   64395   65646   56404   50570
# 第12天   67311   72492   66712   59548   52259
# 第13天   75245   82472   76301   63431   56515
# 第14天   82065   88255   79969   73267   66491
# 第15天   84117   96447   85479   77294   71490
# 第16天   89111  103810   86257   85003   72852
# 第17天   93210  107974   90704   89570   75229
# 第18天   95684  112049   94639   94781   79280
# 第19天   98931  119858   98450  102268   86082
# 第20天  105583  123939  108339  104705   95260
# ...

# %%
import pandas as pd
import numpy as np
fivestore = np.random.randint(100,10000,size=(5,30))
fivestore_cumsum = fivestore.cumsum(axis=1)
fivestore_cumsum

fivestore = pd.DataFrame(fivestore_cumsum,
             columns=[f"第{day}天" for day in range(1,31)],
             index=["A1分店","A2分店","A3分店","A4分店","A5分店"])
new_df = fivestore.T
new_df
type(new_df['A1分店'])
new_df['A1分店']
# Out:
# 第1天       3203
# 第2天       3485
# 第3天       8845
# 第4天       9425
# 第5天      15520
# 第6天      16583
# 第7天      21528
# 第8天      26450
# 第9天      30985
# 第10天     34672
# 第11天     42237
# 第12天     42691
# 第13天     44360
# 第14天     53836
# 第15天     63687
# 第16天     66359
# 第17天     71012
# 第18天     78470
# 第19天     86035
# 第20天     93071
# 第21天    100446
# 第22天    110005
# 第23天    117593
# 第24天    120076
# 第25天    124372
# 第26天    127300
# 第27天    129171
# 第28天    130744
# 第29天    133037
# 第30天    139452
# Name: A1分店, dtype: int64
